# %%
import os, sys
from simulation_utils import run_simulations, load_tree
import oncophylo as op
from anndata import io
import networkx as nx

# %% [markdown]
# ## Simulations for 1 sample

# %%
# set up parameters
n_trials = 10
num_mutations = 20
num_cells = 3000
num_CNAs = 3
num_nodes = 6 
num_samples= 1
num_regions = 20
hom_precision=50.0
save_path = os.path.join(os.getcwd(),  f"hom_precision_{hom_precision}_simulations", "sims_1samples")
seed = 32778826 # randomly generated seed

# %%
results1_df = run_simulations(n_trials,
                             num_mutations,
                             num_cells, 
                             num_CNAs,
                             num_nodes,
                             num_samples,
                             num_regions=num_regions,
                             save_path=save_path,
                             include_LoPhy=True,
                             include_COMPASS=False,
                             include_SCITE=False,
                             include_LACE=False,
                             LoPhy_kwargs={"hom_precision":hom_precision, "het_precision":4.0, "fp":0.02, "fn":0.05},
                             seed=seed)
# Out:
# Sim 0 (seed 166516594)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 1 (seed 2811312517)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 2 (seed 584501261)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 3 (seed 1771135495)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 4 (seed 1757938591)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 5 (seed 2990120679)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 6 (seed 1160117644)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 7 (seed 2598067073)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 8 (seed 3326084201)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 9 (seed 1809465062)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS

# %%
results1_df.to_csv(os.path.join(save_path, "sim_evaluation.csv"))

# %% [markdown]
# ## Simulations for 2 samples

# %%
# set up parameters
n_trials = 10
num_mutations = 20
num_cells = 6000
num_CNAs = 3
num_nodes = 6 
num_samples= 2
num_regions = 20
hom_precision=50.0
save_path = os.path.join(os.getcwd(), f"hom_precision_{hom_precision}_simulations", "sims_2samples")
seed = 23124243 # randomly generated seed

# %%
results2_df = run_simulations(n_trials,
                             num_mutations,
                             num_cells, 
                             num_CNAs,
                             num_nodes,
                             num_samples,
                             num_regions=num_regions,
                             save_path=save_path,
                             include_LoPhy=True,
                             include_COMPASS=False,
                             include_SCITE=False,
                             include_LACE=False,
                             LoPhy_kwargs={"hom_precision":hom_precision, "het_precision":4.0, "fp":0.02, "fn":0.05},
                             seed=seed)
# Out:
# Sim 0 (seed 3684248876)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 1 (seed 1478403473)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 2 (seed 2139584330)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 3 (seed 3594639586)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 4 (seed 3342401003)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 5 (seed 1784190090)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 6 (seed 3230380534)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 7 (seed 1530311423)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 8 (seed 2149725597)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 9 (seed 685288182)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS

# %%
results2_df.to_csv(os.path.join(save_path, "sim_evaluation.csv"))

# %% [markdown]
# ## Simulations for 3 samples

# %%
# set up parameters
n_trials = 10
num_mutations = 20
num_cells = 9000
num_CNAs = 3
num_nodes = 7 
num_samples= 3
num_regions = 20
hom_precision=50.0
save_path = os.path.join(os.getcwd(), f"hom_precision_{hom_precision}_simulations", "sims_3samples")
seed = 23234553 # randomly generated seed

# %%
results3_df = run_simulations(n_trials,
                             num_mutations,
                             num_cells, 
                             num_CNAs,
                             num_nodes,
                             num_samples,
                             num_regions=num_regions,
                             save_path=save_path,
                             include_LoPhy=True,
                             include_COMPASS=False,
                             include_SCITE=False,
                             include_LACE=False,
                             LoPhy_kwargs={"hom_precision":hom_precision, "het_precision":4.0, "fp":0.02, "fn":0.05},
                             seed=seed)
# Out:
# Sim 0 (seed 4061673262)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 1 (seed 65172193)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 2 (seed 696670193)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 3 (seed 4161130315)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 4 (seed 3132057565)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 5 (seed 2275587030)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 6 (seed 844073753)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 7 (seed 2049470333)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 8 (seed 103919340)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS
# Sim 9 (seed 3166705418)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Running COMPASS

# %%
results3_df.to_csv(os.path.join(save_path, "sim_evaluation.csv"))

# %% [markdown]
# ## Simulations for 4 samples

# %%
# set up parameters
n_trials = 10
num_mutations = 20
num_cells = 12000
num_CNAs = 3
num_nodes = 8 
num_samples= 4
num_regions = 20
hom_precision=50.0
save_path = os.path.join(os.getcwd(), f"hom_precision_{hom_precision}_simulations", "sims_4samples")
seed = 567856834 # randomly generated seed

# %%
results4_df = run_simulations(n_trials,
                             num_mutations,
                             num_cells, 
                             num_CNAs,
                             num_nodes,
                             num_samples,
                             num_regions=num_regions,
                             save_path=save_path,
                             include_LoPhy=True,
                             include_COMPASS=False,
                             include_SCITE=False,
                             include_LACE=False,
                             LoPhy_kwargs={"hom_precision":hom_precision, "het_precision":4.0, "fp":0.02, "fn":0.05},
                             seed=seed)

# %%
results4_df.to_csv(os.path.join(save_path, "sim_evaluation.csv"))

# %% [markdown]
# ## Simulations for 5 samples

# %%
n_trials = 10
num_mutations = 20
num_cells = 15000
num_CNAs = 3
num_nodes = 9 
num_samples= 5
num_regions = 20
hom_precision=50.0
save_path = os.path.join(os.getcwd(), f"hom_precision_{hom_precision}_simulations", "sims_5samples")
seed = 884543252 # randomly generated seed

# %%
results5_df = run_simulations(n_trials,
                             num_mutations,
                             num_cells, 
                             num_CNAs,
                             num_nodes,
                             num_samples,
                             num_regions=num_regions,
                             save_path=save_path,
                             include_LoPhy=True,
                             include_COMPASS=False,
                             include_SCITE=False,
                             include_LACE=False,
                             LoPhy_kwargs={"hom_precision":hom_precision, "het_precision":4.0, "fp":0.02, "fn":0.05},
                             seed=seed)

# %%
results5_df.to_csv(os.path.join(save_path, "sim_evaluation.csv"))
