# %%
import os, sys
from simulation_utils import run_simulations, load_tree
import oncophylo as op
from anndata import io
import networkx as nx
import pandas as pd

# %% [markdown]
# ## Simulations for 1 sample

# %%
# set up parameters
n_trials = 10
num_mutations = 20
num_cells = 3000
num_CNAs = 3
num_nodes = 6 
num_samples= 1
num_regions = 20
save_path = os.path.join(os.getcwd(), "simulations_main_3chains", "sims_1samples")
seed = 32778826 # randomly generated seed

# %%
results1_df = run_simulations(n_trials,
                             num_mutations,
                             num_cells, 
                             num_CNAs,
                             num_nodes,
                             num_samples,
                             num_regions=num_regions,
                             save_path=save_path,
                             include_LoPhy=True,
                             include_COMPASS=False,
                             include_SCITE=False,
                             include_LACE=False,
                             LoPhy_kwargs={"n_chains": 3, "iters": 200, "het_precision":4.0, "hom_precision":15.0, "fp":0.02, "fn":0.05},
                             seed=seed)
# Out:
# Sim 0 (seed 1355160669)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 1 (seed 3892933484)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 2 (seed 4002287895)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 3 (seed 1582831946)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 4 (seed 2615660784)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 5 (seed 2909660823)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 6 (seed 3704033281)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 7 (seed 1982065105)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 8 (seed 3454476712)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 9 (seed 2893412019)
# 4
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy

# %%
results1_df.to_csv(os.path.join(save_path, "sim_evaluation.csv"))

# %% [markdown]
# ## Simulations for 2 samples

# %%
# set up parameters
n_trials = 10
num_mutations = 20
num_cells = 6000
num_CNAs = 3
num_nodes = 6 
num_samples= 2
num_regions = 20
save_path = os.path.join(os.getcwd(), "simulations_main_3chains", "sims_2samples")
seed = 23124243 # randomly generated seed

# %%
results2_df = run_simulations(n_trials,
                             num_mutations,
                             num_cells, 
                             num_CNAs,
                             num_nodes,
                             num_samples,
                             num_regions=num_regions,
                             save_path=save_path,
                             include_LoPhy=True,
                             include_COMPASS=False,
                             include_SCITE=False,
                             include_LACE=False,
                             LoPhy_kwargs={"n_chains": 3, "iters": 200, "het_precision":4.0, "hom_precision":15.0, "fp":0.02, "fn":0.05},
                             seed=seed)
# Out:
# Sim 0 (seed 680545790)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 1 (seed 635151212)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 2 (seed 1836321473)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 3 (seed 3548533395)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 4 (seed 2901926519)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 5 (seed 453984171)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 6 (seed 153792327)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 7 (seed 370433292)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 8 (seed 890632987)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 9 (seed 2996023646)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy

# %%
results2_df.to_csv(os.path.join(save_path, "sim_evaluation.csv"))

# %% [markdown]
# ## Simulations for 3 samples

# %%
# set up parameters
n_trials = 10
num_mutations = 20
num_cells = 9000
num_CNAs = 3
num_nodes = 7 
num_samples= 3
num_regions = 20
save_path = os.path.join(os.getcwd(), "simulations_main_3chains", "sims_3samples")
seed = 23234553 # randomly generated seed

# %%
results3_df = run_simulations(n_trials,
                             num_mutations,
                             num_cells, 
                             num_CNAs,
                             num_nodes,
                             num_samples,
                             num_regions=num_regions,
                             save_path=save_path,
                             include_LoPhy=True,
                             include_COMPASS=False,
                             include_SCITE=False,
                             include_LACE=False,
                             LoPhy_kwargs={"n_chains": 3, "iters": 200, "het_precision":4.0, "hom_precision":15.0, "fp":0.02, "fn":0.05},
                             seed=seed)
# Out:
# Sim 0 (seed 3803052508)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 1 (seed 742306664)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 2 (seed 386717865)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 3 (seed 3902655840)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 4 (seed 3554087724)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 5 (seed 606672372)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 6 (seed 109642692)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 7 (seed 302732342)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 8 (seed 2472369987)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 9 (seed 3847039570)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy

# %%
results3_df.to_csv(os.path.join(save_path, "sim_evaluation.csv"))

# %% [markdown]
# ## Simulations for 4 samples

# %%
# set up parameters
n_trials = 10
num_mutations = 20
num_cells = 12000
num_CNAs = 3
num_nodes = 8 
num_samples= 4
num_regions = 20
save_path = os.path.join(os.getcwd(), "simulations_main_3chains", "sims_4samples")
seed = 567856834 # randomly generated seed

# %%
results4_df = run_simulations(n_trials,
                             num_mutations,
                             num_cells, 
                             num_CNAs,
                             num_nodes,
                             num_samples,
                             num_regions=num_regions,
                             save_path=save_path,
                             include_LoPhy=True,
                             include_COMPASS=False,
                             include_SCITE=False,
                             include_LACE=False,
                             LoPhy_kwargs={"n_chains": 3, "iters": 200, "het_precision":4.0, "hom_precision":15.0, "fp":0.02, "fn":0.05},
                             seed=seed)
# Out:
# Sim 0 (seed 2768074173)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 1 (seed 2355926200)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 2 (seed 2795774174)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 3 (seed 1683435622)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 4 (seed 4277463694)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 5 (seed 1695672819)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 6 (seed 737083773)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 7 (seed 529474691)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 8 (seed 499705638)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 9 (seed 2298009093)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy

# %%
results4_df.to_csv(os.path.join(save_path, "sim_evaluation.csv"))

# %% [markdown]
# ## Simulations for 5 samples

# %%
n_trials = 10
num_mutations = 20
num_cells = 15000
num_CNAs = 3
num_nodes = 9 
num_samples= 5
num_regions = 20
save_path = os.path.join(os.getcwd(), "simulations_main_3chains", "sims_5samples")
seed = 884543252 # randomly generated seed

# %%
results5_df = run_simulations(n_trials,
                             num_mutations,
                             num_cells, 
                             num_CNAs,
                             num_nodes,
                             num_samples,
                             num_regions=num_regions,
                             save_path=save_path,
                             include_LoPhy=True,
                             include_COMPASS=False,
                             include_SCITE=False,
                             include_LACE=False,
                             LoPhy_kwargs={"n_chains": 3, "iters": 200, "het_precision":4.0, "hom_precision":15.0, "fp":0.02, "fn":0.05},
                             seed=seed)
# Out:
# Sim 0 (seed 1970775211)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 1 (seed 395975083)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 2 (seed 3416256309)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 3 (seed 3121438772)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 4 (seed 3244321957)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 5 (seed 2466678641)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 6 (seed 226167528)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 7 (seed 1296848341)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 8 (seed 1137111821)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy
# Sim 9 (seed 495039816)
# 3
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/ethank/LoPhy/env/lib/python3.13/site-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# Running LoPhy

# %%
results5_df.to_csv(os.path.join(save_path, "sim_evaluation.csv"))

# %%
df1 = pd.read_csv(os.path.join(os.getcwd(), "simulations_main_3chains", "sims_1samples", "sim_evaluation.csv"), header=0, index_col=0)
df2 = pd.read_csv(os.path.join(os.getcwd(), "simulations_main_3chains", "sims_2samples", "sim_evaluation.csv"), header=0, index_col=0)
df3 = pd.read_csv(os.path.join(os.getcwd(), "simulations_main_3chains", "sims_3samples", "sim_evaluation.csv"), header=0, index_col=0)
df4 = pd.read_csv(os.path.join(os.getcwd(), "simulations_main_3chains", "sims_4samples", "sim_evaluation.csv"), header=0, index_col=0)
df5 = pd.read_csv(os.path.join(os.getcwd(), "simulations_main_3chains", "sims_5samples", "sim_evaluation.csv"), header=0, index_col=0)

df1["Samples"] = 1
df2["Samples"] = 2
df3["Samples"] = 3
df4["Samples"] = 4
df5["Samples"] = 5

# %%
results_df = pd.concat([df2,df3,df4,df5])
results_df = results_df.reset_index(drop=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the 2x2 subplot grid
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# List of metrics and corresponding subplot positions
metrics = [("MCN-MAE", "MCN-MAE"),
           ("TCN_MAE", "TCN_MAE"),
           ("FER", "FER"),
           ("Run time", "Run time")]

# Flatten axes for easy iteration
axes = axes.flatten()

# Plot each metric
for ax, (metric_col, title) in zip(axes, metrics):
    sns.boxplot(data=results_df, x="Samples", y=metric_col, hue="Model", palette="deep", ax=ax, hue_order=["LoPhy", "COMPASS", "SCITE", "LACE"])
    ax.set_title(title)
    ax.set_ylabel(title)
    ax.set_xlabel("Samples")
    ax.legend_.remove()  # Remove individual legends

# Add a single shared legend outside the top-right
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=len(labels), frameon=False)

plt.tight_layout(rect=[0, 0, 1, 0.98])  # Leave space for legend
plt.show()
